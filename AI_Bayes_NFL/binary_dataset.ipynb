# %% [markdown]
# # Notebook for Creation of Binary Dataset

# %% [markdown]
# This notebook was used to create our binary dataset, alongside our thresholds. This notebook focuses on NFL_Merged_Data.csv which contains the relevant data to be used for now.

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Threshold Creation

# %%
stats_playoffs = pd.read_csv("Data/NFL_Merged_Data.csv")

# %% [markdown]
# Thresholds and their meaning better are better explained in the README, under **"Methodologies for Establishing Thresholds"**

# %%
# easy strength of schedule
sos_metric = 0.449
above_avg_srs = 0
# above average Offensive SRS and Defensive SRS
above_avg_osrs = 2
above_avg_dsrs = stats_playoffs["DSRS"].median()
Avg_Points_Allowed_th = 21
Avg_Points_Scored_th = 24
# 7 pts or above for MoV is considered above average
mov_threshold = 7
# above 50 pts differential means a strong team
pd_threshold = 50
# above 59% is a good win percentage
wp_threshold = 0.59

# offense completes more than 55% of the time
completion_threshold_o = 0.55
# average passing yards per play
ave_passing_o = 6.6
# above average rushing
ave_rushing_o = 4.5
# defense_completion_percentage
completion_d = 0.55
# defense average passing yards gained
pass_gain_def = 5.9
rush_gain_def = 4.5
# defense success rate pass and run
succ_rate_pass_def = 0.43
succ_rate_rush_def = 0.4


epa_pass_o = 0.15
epa_run_o = 0

epa_pass_d = -0.02
epa_run_d = -0.06
# offense success rate
success_rate_pass_o = 0.46
success_rate_run_o = 0.4
# more than 16 interceptions
interception_d = 16
# wpa metrics
wpa_pass_o = 0.002
wpa_rush_o = 0

wpa_pass_d = 0
wpa_rush_d = -0.0018

avg_succ_rate = 0.86 / 2

# %%
binary_dataset = stats_playoffs.copy()

# %%
# This modifies the columns in the binary dataset to be between 0 and 1,
# depending on the thresholds
binary_dataset["offense_completion_percentage"] = np.where(binary_dataset["offense_completion_percentage"] >= completion_threshold_o, 1, 0)
binary_dataset["offense_ave_yards_gained_pass"] = np.where(binary_dataset["offense_ave_yards_gained_pass"] > ave_passing_o, 1, 0)
binary_dataset["offense_ave_yards_gained_run"] = np.where(binary_dataset["offense_ave_yards_gained_run"] > ave_rushing_o, 1, 0)

binary_dataset["defense_completion_percentage"] = np.where(binary_dataset["defense_completion_percentage"] > completion_d, 1, 0)
binary_dataset["defense_ave_yards_gained_pass"] = np.where(binary_dataset["defense_ave_yards_gained_pass"] > pass_gain_def, 1, 0)
binary_dataset["defense_ave_yards_gained_run"] = np.where(binary_dataset["defense_ave_yards_gained_run"] > rush_gain_def, 1, 0)
binary_dataset["defense_success_rate_pass"] = np.where(binary_dataset["defense_success_rate_pass"] > succ_rate_pass_def, 1, 0)
binary_dataset["defense_success_rate_run"] = np.where(binary_dataset["defense_success_rate_run"] > succ_rate_rush_def, 1, 0)

binary_dataset["offense_ave_epa_pass"] = np.where(binary_dataset["offense_ave_epa_pass"] > epa_pass_o, 1, 0)
binary_dataset["offense_ave_epa_run"] = np.where(binary_dataset["offense_ave_epa_run"] > epa_run_o, 1, 0)
binary_dataset["defense_ave_epa_pass"] = np.where(binary_dataset["defense_ave_epa_pass"] > epa_pass_d, 1, 0)
binary_dataset["defense_ave_epa_run"] = np.where(binary_dataset["defense_ave_epa_run"] > epa_run_d, 1, 0)
binary_dataset["offense_success_rate_pass"] = np.where(binary_dataset["offense_success_rate_pass"] > success_rate_pass_o, 1, 0)

binary_dataset["offense_success_rate_run"] = np.where(binary_dataset["offense_success_rate_run"] > success_rate_run_o, 1, 0)
binary_dataset["defense_n_interceptions"] = np.where(binary_dataset["defense_n_interceptions"] > interception_d, 1, 0)
binary_dataset["offense_ave_wpa_pass"] = np.where(binary_dataset["offense_ave_wpa_pass"] > wpa_pass_o, 1, 0)
binary_dataset["offense_ave_wpa_run"] = np.where(binary_dataset["offense_ave_wpa_run"] > wpa_rush_o, 1, 0)
binary_dataset["defense_ave_wpa_pass"] = np.where(binary_dataset["defense_ave_wpa_pass"] > wpa_pass_d, 1, 0)
binary_dataset["defense_ave_wpa_run"] = np.where(binary_dataset["defense_ave_wpa_run"] > wpa_rush_d, 1, 0)

# from 1st
binary_dataset["MoV"] = np.where(binary_dataset["MoV"] >= mov_threshold, 1, 0)
binary_dataset["PD"] = np.where(binary_dataset["PD"] > pd_threshold, 1, 0)
binary_dataset["W-L%"] = np.where(binary_dataset["W-L%"] > wp_threshold, 1, 0)

binary_dataset["SoS"] = np.where(binary_dataset["SoS"] > sos_metric, 1, 0)
binary_dataset["SRS"] = np.where(binary_dataset["SRS"] > above_avg_srs, 1, 0)
binary_dataset["OSRS"] = np.where(binary_dataset["OSRS"] > above_avg_osrs, 1, 0)
binary_dataset["DSRS"] = np.where(binary_dataset["DSRS"] > above_avg_dsrs, 1, 0)

# calculated values
binary_dataset["Avg_Points_Allowed"] = np.where(binary_dataset["Avg_Points_Allowed"] >= Avg_Points_Allowed_th, 1, 0)
binary_dataset["Avg_Points_Scored"] = np.where(binary_dataset["Avg_Points_Scored"] >= Avg_Points_Scored_th, 1, 0)
binary_dataset["Avg_offense_success_rate"] = np.where(binary_dataset["Avg_offense_success_rate"] >= avg_succ_rate, 1, 0)

# %%
binary_dataset_columns = [
    "Playoffs", "offense_completion_percentage", "offense_ave_yards_gained_pass", "offense_ave_yards_gained_run", 
    "defense_completion_percentage", "defense_ave_yards_gained_pass", "defense_ave_yards_gained_run", 
    "defense_success_rate_pass", "defense_success_rate_run", "offense_ave_epa_pass", "offense_ave_epa_run",
    "defense_ave_epa_pass", "defense_ave_epa_run", "offense_success_rate_pass", "offense_success_rate_run",
    "defense_n_interceptions", 'offense_ave_wpa_pass', 'offense_ave_wpa_run', 'defense_ave_wpa_pass', 'defense_ave_wpa_run',
    'PD', 'W-L%', 'MoV', 'Strong_Start', 'SoS', 'SRS', 'OSRS', 'DSRS', 'Avg_Points_Allowed', 'Avg_Points_Scored',
    'Avg_offense_success_rate'
]
binary_dataset = binary_dataset[binary_dataset_columns]

# %%
binary_dataset.to_csv("Data/Binary_Dataset.csv")

# %% [markdown]
# ## Correlation Matrix to support findings and identify more

# %%
binary_dataset.corr()
# Out:
#                                Playoffs  offense_completion_percentage  \
# Playoffs                       1.000000                       0.286311
# offense_completion_percentage  0.286311                       1.000000
# offense_ave_yards_gained_pass  0.354939                       0.405040
# offense_ave_yards_gained_run   0.181826                       0.162928
# defense_completion_percentage -0.195358                       0.105735
# defense_ave_yards_gained_pass -0.300987                       0.042485
# defense_ave_yards_gained_run  -0.070669                       0.136234
# defense_success_rate_pass     -0.247765                       0.070287
# defense_success_rate_run      -0.071149                       0.150505
# offense_ave_epa_pass           0.380925                       0.272325
# offense_ave_epa_run            0.209015                       0.200670
# defense_ave_epa_pass          -0.337285                      -0.004733
# defense_ave_epa_run           -0.170306                       0.049485
# offense_success_rate_pass      0.392114                       0.489112
# offense_success_rate_run       0.222288                       0.283407
# defense_n_interceptions        0.215158                      -0.005369
# offense_ave_wpa_pass           0.414335                       0.394252
# offense_ave_wpa_run            0.313149                       0.262571
# defense_ave_wpa_pass          -0.307454                       0.058585
# defense_ave_wpa_run           -0.276262                       0.010629
# PD                             0.677824                       0.307759
# W-L%                           0.830031                       0.267663
# MoV                            0.519173                       0.208431
# Strong_Start                   0.287828                       0.151669
# SoS                           -0.116944                      -0.044146
# SRS                            0.610701                       0.298105
# OSRS                           0.434823                       0.338025
# DSRS                           0.413561                       0.142658
# Avg_Points_Allowed            -0.416409                      -0.075966
# Avg_Points_Scored              0.468894                       0.394858
# Avg_offense_success_rate       0.346876                       0.480454
#
#                                offense_ave_yards_gained_pass  \
# Playoffs                                            0.354939
# offense_completion_percentage                       0.405040
# offense_ave_yards_gained_pass                       1.000000
# offense_ave_yards_gained_run                        0.163457
# defense_completion_percentage                       0.078830
# defense_ave_yards_gained_pass                       0.054609
# defense_ave_yards_gained_run                        0.115683
# defense_success_rate_pass                           0.082655
# defense_success_rate_run                            0.158666
# offense_ave_epa_pass                                0.620872
# offense_ave_epa_run                                 0.157925
# defense_ave_epa_pass                                0.011056
# defense_ave_epa_run                                 0.061136
# offense_success_rate_pass                           0.688065
# offense_success_rate_run                            0.294442
# defense_n_interceptions                             0.018475
# offense_ave_wpa_pass                                0.659235
# offense_ave_wpa_run                                 0.254312
# defense_ave_wpa_pass                                0.076807
# defense_ave_wpa_run                                 0.004329
# PD                                                  0.421276
# W-L%                                                0.378845
# MoV                                                 0.334805
# Strong_Start                                        0.194489
# SoS                                                -0.062605
# SRS                                                 0.347540
# OSRS                                                0.575322
# DSRS                                                0.040106
# Avg_Points_Allowed                                 -0.011324
# Avg_Points_Scored                                   0.616522
# Avg_offense_success_rate                            0.537854
#
#                                offense_ave_yards_gained_run  \
# Playoffs                                           0.181826
# offense_completion_percentage                      0.162928
# offense_ave_yards_gained_pass                      0.163457
# offense_ave_yards_gained_run                       1.000000
# defense_completion_percentage                      0.123302
# defense_ave_yards_gained_pass                      0.067926
# defense_ave_yards_gained_run                       0.110450
# defense_success_rate_pass                          0.080000
# defense_success_rate_run                           0.157311
# offense_ave_epa_pass                               0.119444
# offense_ave_epa_run                                0.576946
# defense_ave_epa_pass                               0.064743
# defense_ave_epa_run                                0.063700
# offense_success_rate_pass                          0.118092
# offense_success_rate_run                           0.501715
# defense_n_interceptions                           -0.015946
# offense_ave_wpa_pass                               0.137991
# offense_ave_wpa_run                                0.520499
# defense_ave_wpa_pass                               0.086381
# defense_ave_wpa_run                                0.086779
# PD                                                 0.214169
# W-L%                                               0.191214
# MoV                                                0.149166
# Strong_Start                                       0.032133
# SoS                                               -0.067189
# SRS                                                0.154337
# OSRS                                               0.202446
# DSRS                                               0.074191
# Avg_Points_Allowed                                 0.024358
# Avg_Points_Scored                                  0.237175
# Avg_offense_success_rate                           0.365659
#
#                                defense_completion_percentage  \
# Playoffs                                           -0.195358
# offense_completion_percentage                       0.105735
# offense_ave_yards_gained_pass                       0.078830
# offense_ave_yards_gained_run                        0.123302
# defense_completion_percentage                       1.000000
# defense_ave_yards_gained_pass                       0.466583
# defense_ave_yards_gained_run                        0.179060
# defense_success_rate_pass                           0.664835
# defense_success_rate_run                            0.293752
# offense_ave_epa_pass                                0.028495
# offense_ave_epa_run                                 0.079517
# defense_ave_epa_pass                                0.456188
# defense_ave_epa_run                                 0.255247
# offense_success_rate_pass                           0.067997
# offense_success_rate_run                            0.098047
# defense_n_interceptions                            -0.208365
# offense_ave_wpa_pass                                0.096984
# offense_ave_wpa_run                                 0.088333
# defense_ave_wpa_pass                                0.424032
# defense_ave_wpa_run                                 0.274549
# PD                                                 -0.235835
# W-L%                                               -0.225095
# MoV                                                -0.159931
# Strong_Start                                       -0.117734
# SoS                                                 0.010865
# SRS                                                -0.247426
# OSRS                                               -0.081317
# DSRS                                               -0.260695
# Avg_Points_Allowed                                  0.381595
# Avg_Points_Scored                                  -0.024960
# Avg_offense_success_rate                            0.128806
#
#                                defense_ave_yards_gained_pass  \
# Playoffs                                           -0.300987
# offense_completion_percentage                       0.042485
# offense_ave_yards_gained_pass                       0.054609
# offense_ave_yards_gained_run                        0.067926
# defense_completion_percentage                       0.466583
# defense_ave_yards_gained_pass                       1.000000
# defense_ave_yards_gained_run                        0.210784
# defense_success_rate_pass                           0.559193
# defense_success_rate_run                            0.232692
# offense_ave_epa_pass                               -0.004296
# offense_ave_epa_run                                -0.003891
# defense_ave_epa_pass                                0.664580
# defense_ave_epa_run                                 0.259784
# offense_success_rate_pass                           0.007886
# offense_success_rate_run                            0.051645
# defense_n_interceptions                            -0.208711
# offense_ave_wpa_pass                                0.052357
# offense_ave_wpa_run                                 0.026602
# defense_ave_wpa_pass                                0.567985
# defense_ave_wpa_run                                 0.332456
# PD                                                 -0.328221
# W-L%                                               -0.334782
# MoV                                                -0.283096
# Strong_Start                                       -0.123627
# SoS                                                 0.019466
# SRS                                                -0.351984
# OSRS                                               -0.106969
# DSRS                                               -0.475674
# Avg_Points_Allowed                                  0.568085
# Avg_Points_Scored                                  -0.064257
# Avg_offense_success_rate                            0.070532
#
#                                defense_ave_yards_gained_run  \
# Playoffs                                          -0.070669
# offense_completion_percentage                      0.136234
# offense_ave_yards_gained_pass                      0.115683
# offense_ave_yards_gained_run                       0.110450
# defense_completion_percentage                      0.179060
# defense_ave_yards_gained_pass                      0.210784
# defense_ave_yards_gained_run                       1.000000
# defense_success_rate_pass                          0.208104
# defense_success_rate_run                           0.479521
# offense_ave_epa_pass                               0.083996
# offense_ave_epa_run                                0.097679
# defense_ave_epa_pass                               0.141121
# defense_ave_epa_run                                0.514900
# offense_success_rate_pass                          0.124579
# offense_success_rate_run                           0.122666
# defense_n_interceptions                           -0.041504
# offense_ave_wpa_pass                               0.144796
# offense_ave_wpa_run                                0.178876
# defense_ave_wpa_pass                               0.197581
# defense_ave_wpa_run                                0.440896
# PD                                                -0.094956
# W-L%                                              -0.087188
# MoV                                               -0.055866
# Strong_Start                                       0.006698
# SoS                                                0.054510
# SRS                                               -0.154553
# OSRS                                               0.068626
# DSRS                                              -0.209933
# Avg_Points_Allowed                                 0.268981
# Avg_Points_Scored                                  0.099669
# Avg_offense_success_rate                           0.155776
#
#                                defense_success_rate_pass  \
# Playoffs                                       -0.247765
# offense_completion_percentage                   0.070287
# offense_ave_yards_gained_pass                   0.082655
# offense_ave_yards_gained_run                    0.080000
# defense_completion_percentage                   0.664835
# defense_ave_yards_gained_pass                   0.559193
# defense_ave_yards_gained_run                    0.208104
# defense_success_rate_pass                       1.000000
# defense_success_rate_run                        0.295592
# offense_ave_epa_pass                            0.040204
# offense_ave_epa_run                             0.078721
# defense_ave_epa_pass                            0.613873
# defense_ave_epa_run                             0.297445
# offense_success_rate_pass                       0.066249
# offense_success_rate_run                        0.079354
# defense_n_interceptions                        -0.221040
# offense_ave_wpa_pass                            0.100629
# offense_ave_wpa_run                             0.058033
# defense_ave_wpa_pass                            0.528177
# defense_ave_wpa_run                             0.306629
# PD                                             -0.279187
# W-L%                                           -0.271595
# MoV                                            -0.226391
# Strong_Start                                   -0.085735
# SoS                                             0.009857
# SRS                                            -0.318783
# OSRS                                           -0.081836
# DSRS                                           -0.400439
# Avg_Points_Allowed                              0.485495
# Avg_Points_Scored                              -0.037688
# Avg_offense_success_rate                        0.105117
#
#                                defense_success_rate_run  offense_ave_epa_pass  \
# Playoffs                                      -0.071149              0.380925
# offense_completion_percentage                  0.150505              0.272325
# offense_ave_yards_gained_pass                  0.158666              0.620872
# offense_ave_yards_gained_run                   0.157311              0.119444
# defense_completion_percentage                  0.293752              0.028495
# defense_ave_yards_gained_pass                  0.232692             -0.004296
# defense_ave_yards_gained_run                   0.479521              0.083996
# defense_success_rate_pass                      0.295592              0.040204
# defense_success_rate_run                       1.000000              0.146576
# offense_ave_epa_pass                           0.146576              1.000000
# offense_ave_epa_run                            0.146010              0.161643
# defense_ave_epa_pass                           0.207345             -0.010660
# defense_ave_epa_run                            0.580094              0.079727
# offense_success_rate_pass                      0.139590              0.539195
# offense_success_rate_run                       0.123320              0.243088
# defense_n_interceptions                       -0.127670              0.034136
# offense_ave_wpa_pass                           0.197393              0.607185
# offense_ave_wpa_run                            0.200556              0.240721
# defense_ave_wpa_pass                           0.166018              0.010274
# defense_ave_wpa_run                            0.481605              0.015565
# PD                                            -0.064278              0.429390
# W-L%                                          -0.080987              0.421627
# MoV                                           -0.094475              0.439978
# Strong_Start                                   0.011310              0.261085
# SoS                                           -0.004334             -0.048882
# SRS                                           -0.126604              0.336712
# OSRS                                           0.057759              0.509162
# DSRS                                          -0.174047              0.094970
# Avg_Points_Allowed                             0.255205             -0.067851
# Avg_Points_Scored                              0.104503              0.511181
# Avg_offense_success_rate                       0.163601              0.457528
#
#                                ...      W-L%       MoV  Strong_Start  \
# Playoffs                       ...  0.830031  0.519173      0.287828
# offense_completion_percentage  ...  0.267663  0.208431      0.151669
# offense_ave_yards_gained_pass  ...  0.378845  0.334805      0.194489
# offense_ave_yards_gained_run   ...  0.191214  0.149166      0.032133
# defense_completion_percentage  ... -0.225095 -0.159931     -0.117734
# defense_ave_yards_gained_pass  ... -0.334782 -0.283096     -0.123627
# defense_ave_yards_gained_run   ... -0.087188 -0.055866      0.006698
# defense_success_rate_pass      ... -0.271595 -0.226391     -0.085735
# defense_success_rate_run       ... -0.080987 -0.094475      0.011310
# offense_ave_epa_pass           ...  0.421627  0.439978      0.261085
# offense_ave_epa_run            ...  0.214015  0.214951      0.073210
# defense_ave_epa_pass           ... -0.384556 -0.331072     -0.149054
# defense_ave_epa_run            ... -0.201274 -0.203138     -0.033681
# offense_success_rate_pass      ...  0.383575  0.306925      0.172633
# offense_success_rate_run       ...  0.210942  0.193744      0.080404
# defense_n_interceptions        ...  0.251643  0.272041      0.147870
# offense_ave_wpa_pass           ...  0.460556  0.304394      0.217589
# offense_ave_wpa_run            ...  0.305208  0.249517      0.097247
# defense_ave_wpa_pass           ... -0.306666 -0.196805     -0.163491
# defense_ave_wpa_run            ... -0.311878 -0.269002     -0.043990
# PD                             ...  0.750540  0.611925      0.269204
# W-L%                           ...  1.000000  0.548949      0.278753
# MoV                            ...  0.548949  1.000000      0.247069
# Strong_Start                   ...  0.278753  0.247069      1.000000
# SoS                            ... -0.102479 -0.074781     -0.047103
# SRS                            ...  0.635065  0.416429      0.276928
# OSRS                           ...  0.497932  0.484118      0.223597
# DSRS                           ...  0.453040  0.338240      0.175691
# Avg_Points_Allowed             ... -0.453186 -0.338110     -0.174361
# Avg_Points_Scored              ...  0.530727  0.467084      0.211739
# Avg_offense_success_rate       ...  0.325407  0.279700      0.205353
#
#                                     SoS       SRS      OSRS      DSRS  \
# Playoffs                      -0.116944  0.610701  0.434823  0.413561
# offense_completion_percentage -0.044146  0.298105  0.338025  0.142658
# offense_ave_yards_gained_pass -0.062605  0.347540  0.575322  0.040106
# offense_ave_yards_gained_run  -0.067189  0.154337  0.202446  0.074191
# defense_completion_percentage  0.010865 -0.247426 -0.081317 -0.260695
# defense_ave_yards_gained_pass  0.019466 -0.351984 -0.106969 -0.475674
# defense_ave_yards_gained_run   0.054510 -0.154553  0.068626 -0.209933
# defense_success_rate_pass      0.009857 -0.318783 -0.081836 -0.400439
# defense_success_rate_run      -0.004334 -0.126604  0.057759 -0.174047
# offense_ave_epa_pass          -0.048882  0.336712  0.509162  0.094970
# offense_ave_epa_run           -0.042054  0.223117  0.284744  0.104682
# defense_ave_epa_pass          -0.009286 -0.460420 -0.162964 -0.494502
# defense_ave_epa_run            0.023346 -0.252097 -0.024065 -0.305710
# offense_success_rate_pass     -0.072601  0.366873  0.509620  0.104640
# offense_success_rate_run      -0.030674  0.225950  0.338094  0.059663
# defense_n_interceptions        0.008300  0.296643  0.154040  0.263858
# offense_ave_wpa_pass          -0.067313  0.372037  0.520592  0.091502
# offense_ave_wpa_run           -0.025865  0.236010  0.339298  0.099117
# defense_ave_wpa_pass          -0.007902 -0.330362 -0.058572 -0.431242
# defense_ave_wpa_run            0.046451 -0.314837 -0.081244 -0.335321
# PD                            -0.100818  0.680523  0.590693  0.462513
# W-L%                          -0.102479  0.635065  0.497932  0.453040
# MoV                           -0.074781  0.416429  0.484118  0.338240
# Strong_Start                  -0.047103  0.276928  0.223597  0.175691
# SoS                            1.000000  0.058645  0.009762  0.079866
# SRS                            0.058645  1.000000  0.529154  0.583840
# OSRS                           0.009762  0.529154  1.000000  0.134870
# DSRS                           0.079866  0.583840  0.134870  1.000000
# Avg_Points_Allowed             0.018176 -0.520074 -0.134454 -0.704705
# Avg_Points_Scored             -0.141852  0.504009  0.753981  0.151509
# Avg_offense_success_rate      -0.005466  0.348867  0.505665  0.076773
#
#                                Avg_Points_Allowed  Avg_Points_Scored  \
# Playoffs                                -0.416409           0.468894
# offense_completion_percentage           -0.075966           0.394858
# offense_ave_yards_gained_pass           -0.011324           0.616522
# offense_ave_yards_gained_run             0.024358           0.237175
# defense_completion_percentage            0.381595          -0.024960
# defense_ave_yards_gained_pass            0.568085          -0.064257
# defense_ave_yards_gained_run             0.268981           0.099669
# defense_success_rate_pass                0.485495          -0.037688
# defense_success_rate_run                 0.255205           0.104503
# offense_ave_epa_pass                    -0.067851           0.511181
# offense_ave_epa_run                     -0.025365           0.316816
# defense_ave_epa_pass                     0.572156          -0.135125
# defense_ave_epa_run                      0.345408          -0.019636
# offense_success_rate_pass               -0.036183           0.594544
# offense_success_rate_run                 0.046620           0.343287
# defense_n_interceptions                 -0.262268           0.127137
# offense_ave_wpa_pass                    -0.045057           0.542009
# offense_ave_wpa_run                     -0.004831           0.378540
# defense_ave_wpa_pass                     0.492974          -0.021673
# defense_ave_wpa_run                      0.416861          -0.063684
# PD                                      -0.461557           0.631368
# W-L%                                    -0.453186           0.530727
# MoV                                     -0.338110           0.467084
# Strong_Start                            -0.174361           0.211739
# SoS                                      0.018176          -0.141852
# SRS                                     -0.520074           0.504009
# OSRS                                    -0.134454           0.753981
# DSRS                                    -0.704705           0.151509
# Avg_Points_Allowed                       1.000000          -0.110069
# Avg_Points_Scored                       -0.110069           1.000000
# Avg_offense_success_rate                 0.022396           0.527652
#
#                                Avg_offense_success_rate
# Playoffs                                       0.346876
# offense_completion_percentage                  0.480454
# offense_ave_yards_gained_pass                  0.537854
# offense_ave_yards_gained_run                   0.365659
# defense_completion_percentage                  0.128806
# defense_ave_yards_gained_pass                  0.070532
# defense_ave_yards_gained_run                   0.155776
# defense_success_rate_pass                      0.105117
# defense_success_rate_run                       0.163601
# offense_ave_epa_pass                           0.457528
# offense_ave_epa_run                            0.446441
# defense_ave_epa_pass                           0.061402
# defense_ave_epa_run                            0.121243
# offense_success_rate_pass                      0.652541
# offense_success_rate_run                       0.640221
# defense_n_interceptions                       -0.049822
# offense_ave_wpa_pass                           0.498126
# offense_ave_wpa_run                            0.498370
# defense_ave_wpa_pass                           0.120597
# defense_ave_wpa_run                            0.078851
# PD                                             0.367064
# W-L%                                           0.325407
# MoV                                            0.279700
# Strong_Start                                   0.205353
# SoS                                           -0.005466
# SRS                                            0.348867
# OSRS                                           0.505665
# DSRS                                           0.076773
# Avg_Points_Allowed                             0.022396
# Avg_Points_Scored                              0.527652
# Avg_offense_success_rate                       1.000000
#
# [31 rows x 31 columns]

# %%
# epa wpa thresholds
spearman_corr = binary_dataset.corr(method='spearman')

# %%
spearman_corr.to_csv("Data/result_matrix.csv")
